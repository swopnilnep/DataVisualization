# %% [markdown]
# Author: Swopnil N. Shrestha <br>
# Organization: Luther College <br>
# Email: swopnil@pm.me <br>
# Version: 0.0.1

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/data/bikeshare/data/boston/boston.csv")
stations = pd.read_csv("/data/bikeshare/data/boston/stations.csv")

# %%
# View dataFrame
df
# Out:
#           seq_id  hubway_id  status  duration           start_date  \
# 0              1          8  Closed         9   7/28/2011 10:12:00
# 1              2          9  Closed       220   7/28/2011 10:21:00
# 2              3         10  Closed        56   7/28/2011 10:33:00
# 3              4         11  Closed        64   7/28/2011 10:35:00
# 4              5         12  Closed        12   7/28/2011 10:37:00
# 5              6         13  Closed        19   7/28/2011 10:39:00
# 6              7         14  Closed        24   7/28/2011 10:47:00
# 7              8         15  Closed         7   7/28/2011 10:48:00
# 8              9         16  Closed         8   7/28/2011 11:01:00
# 9             10         17  Closed      1108   7/28/2011 11:55:00
# 10            11         18  Closed      1055   7/28/2011 11:55:00
# 11            12         19  Closed      1042   7/28/2011 11:55:00
# 12            13         23  Closed       994   7/28/2011 12:00:00
# ...

# %%
# View Stations
stations
# Out:
#       id terminal                                            station  \
# 0      3   B32006                             Colleges of the Fenway
# 1      4   C32000                        Tremont St. at Berkeley St.
# 2      5   B32012                 Northeastern U / North Parking Lot
# 3      6   D32000                           Cambridge St. at Joy St.
# 4      7   A32000                                           Fan Pier
# 5      8   A32001      Union Square - Brighton Ave. at Cambridge St.
# 6      9   A32002                      Agganis Arena - 925 Comm Ave.
# 7     10   A32003                      B.U. Central - 725 Comm. Ave.
# 8     11   A32004                           Longwood Ave / Binney St
# 9     12   B32002                    Ruggles Station / Columbus Ave.
# 10    13   C32002             Boston Medical Center - 721 Mass. Ave.
# 11    14   B32003   HMS / HSPH - Ave. Louis Pasteur at Longwood Ave.
# 12    15   A32005  Harvard Real Estate - Brighton Mills - 370 Wes...
# ...

# %%
df.describe()
# Out:
#              seq_id     hubway_id      duration    strt_statn     end_statn  \
# count  1.579025e+06  1.579025e+06  1.579025e+06  1.579011e+06  1.578980e+06
# mean   7.895130e+05  8.865317e+05  1.200280e+03  5.438039e+01  5.425603e+01
# std    4.558254e+05  5.064783e+05  2.653539e+04  3.364295e+01  3.347219e+01
# min    1.000000e+00  8.000000e+00 -6.900000e+03  3.000000e+00  3.000000e+00
# 25%    3.947570e+05  4.465250e+05  4.120000e+02  2.700000e+01  2.900000e+01
# 50%    7.895130e+05  8.950440e+05  6.600000e+02  4.800000e+01  4.800000e+01
# 75%    1.184269e+06  1.328083e+06  1.082000e+03  7.400000e+01  7.400000e+01
# max    1.579025e+06  1.748022e+06  1.199446e+07  1.450000e+02  1.450000e+02
#
#           birth_date
# count  350644.000000
# mean     1976.295322
# std        10.999742
# min      1932.000000
# 25%      1969.000000
# 50%      1979.000000
# 75%      1985.000000
# max      1995.000000

# %% [markdown]
# * 10 most popular stations
# * Distribution of riding duration (histogram)
# * Average age of riders
# * Pie chart of rider gender
# * Most popular zip codes
